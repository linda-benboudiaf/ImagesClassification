# %%
import torch 
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, models, transforms
import time
import torch.nn as nn
import torch.optim as optim
import numpy as np
data_dir = "/home/lbenboudiaf/Bureau/ImageClassificationWithDeepLearning/GroceryStoreDataset/dataset/dataset2"
model_name = "squeezenet"
num_classes = 81
batch_size = 8
num_epochs = 100 #Valeur Initiale par défaut comme dans le TP du Prof 
feature_extract = True
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25, is_inception=False):
    since = time.time()
    
    val_acc_history = []
    
    loss_val = []
    loss_train = []
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # récupéré le model et calculer sa fonction loss 
                    if is_inception and phase == 'train':
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss = loss1 + 0.4*loss2
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase, Backward 
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)
            
            if phase == 'train':
                loss_train.append(epoch_loss)
            else:
                loss_val.append(epoch_loss)
                
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history, loss_train, loss_val
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
#Definition du model Squeezenet.
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    model_ft = None
    input_size = 0

    if model_name == "squeezenet":
        model_ft = models.squeezenet1_0(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        model_ft.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))
        model_ft.num_classes = num_classes
        input_size = 224
    else:
        print("Invalid model name")
        exit()

    return model_ft, input_size

# Initialisé le model pour ce dataset 
model_ft, input_size = initialize_model(model_name, num_classes, feature_extract, use_pretrained=True)
import os
# Augmentaion et normalisation de données pour le jeux d'apprentissage.  
# Normalisation des jeux de test et de validation 
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")

# Generation de jeux d'apprentissage et de validation 
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val', 'test']}
# Creation des dataloaders pour jeux d'apprentissage et de validation. 
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val', 'test']}

# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Envoyer le model au GPU
model_ft = model_ft.to(device)
params_to_update = model_ft.parameters()
print("Params to learn:")
if feature_extract:
    params_to_update = []
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)
else:
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            print("\t",name)

# Observation des paramètres sont optimisé 
optimizer_ft = optim.SGD(params_to_update, lr=0.0001, momentum=0.9)
# Out:
# Initializing Datasets and Dataloaders...
# Params to learn:
# 	 classifier.1.weight
# 	 classifier.1.bias

# %%
import copy
import matplotlib.pyplot as plt
scratch_model,_ = initialize_model(model_name, num_classes, feature_extract=False, use_pretrained=False)
scratch_model = scratch_model.to(device)
scratch_optimizer = optim.SGD(scratch_model.parameters(), lr=0.001, momentum=0.9)
scratch_criterion = nn.CrossEntropyLoss()
_,scratch_hist, train_loss, val_loss = train_model(scratch_model, dataloaders_dict, scratch_criterion, scratch_optimizer, num_epochs=num_epochs, is_inception=(model_name=="inception"))

#ohist = []
shist = []

#ohist = [h.cpu().numpy() for h in hist]
shist = [h.cpu().numpy() for h in scratch_hist]
# Out:
# Epoch 0/99
# ----------
# train Loss: 2.5978 Acc: 0.3457
# val Loss: 1.8525 Acc: 0.3378
#
# Epoch 1/99
# ----------
# train Loss: 1.2244 Acc: 0.4074
# val Loss: 1.2439 Acc: 0.3750
#
# Epoch 2/99
# ----------
# train Loss: 1.1817 Acc: 0.3333
# val Loss: 1.0559 Acc: 0.4459
#
# Epoch 3/99
# ----------
# train Loss: 1.2034 Acc: 0.4198
# val Loss: 1.4785 Acc: 0.3378
#
# Epoch 4/99
# ----------
# train Loss: 1.1517 Acc: 0.4074
# val Loss: 1.5052 Acc: 0.3378
#
# Epoch 5/99
# ----------
# train Loss: 1.0340 Acc: 0.5062
# val Loss: 2.1573 Acc: 0.3784
#
# Epoch 6/99
# ----------
# train Loss: 1.1027 Acc: 0.5062
# val Loss: 1.0454 Acc: 0.4730
#
# Epoch 7/99
# ----------
# train Loss: 1.0251 Acc: 0.5802
# val Loss: 1.4958 Acc: 0.3682
#
# Epoch 8/99
# ----------
# train Loss: 1.0106 Acc: 0.4815
# val Loss: 1.4165 Acc: 0.4189
#
# Epoch 9/99
# ----------
# train Loss: 0.7996 Acc: 0.6667
# val Loss: 1.0716 Acc: 0.4730
#
# Epoch 10/99
# ----------
# train Loss: 0.9277 Acc: 0.6049
# val Loss: 1.1395 Acc: 0.5270
#
# Epoch 11/99
# ----------
# train Loss: 0.9047 Acc: 0.6790
# val Loss: 1.7002 Acc: 0.4459
#
# Epoch 12/99
# ----------
# train Loss: 0.8565 Acc: 0.5679
# val Loss: 1.1474 Acc: 0.5608
#
# Epoch 13/99
# ----------
# train Loss: 0.7207 Acc: 0.6914
# val Loss: 1.2972 Acc: 0.5439
#
# Epoch 14/99
# ----------
# train Loss: 0.6064 Acc: 0.6914
# val Loss: 2.8177 Acc: 0.3919
#
# Epoch 15/99
# ----------
# train Loss: 1.2251 Acc: 0.5679
# val Loss: 0.9360 Acc: 0.4764
#
# Epoch 16/99
# ----------
# train Loss: 1.0092 Acc: 0.6420
# val Loss: 1.4895 Acc: 0.4257
#
# Epoch 17/99
# ----------
# train Loss: 0.9599 Acc: 0.5802
# val Loss: 1.0039 Acc: 0.5642
#
# Epoch 18/99
# ----------
# train Loss: 0.7369 Acc: 0.7284
# val Loss: 1.7746 Acc: 0.4561
#
# Epoch 19/99
# ----------
# train Loss: 0.8277 Acc: 0.6543
# val Loss: 1.2549 Acc: 0.4257
#
# Epoch 20/99
# ----------
# train Loss: 0.8656 Acc: 0.5556
# val Loss: 1.0827 Acc: 0.5811
#
# Epoch 21/99
# ----------
# train Loss: 0.7253 Acc: 0.6790
# val Loss: 1.1781 Acc: 0.5946
#
# Epoch 22/99
# ----------
# train Loss: 0.7541 Acc: 0.6296
# val Loss: 1.2289 Acc: 0.4730
#
# Epoch 23/99
# ----------
# train Loss: 0.6593 Acc: 0.6790
# val Loss: 1.6454 Acc: 0.5000
#
# Epoch 24/99
# ----------
# train Loss: 0.6590 Acc: 0.7407
# val Loss: 1.1033 Acc: 0.5270
#
# Epoch 25/99
# ----------
# train Loss: 0.9355 Acc: 0.6420
# val Loss: 0.9558 Acc: 0.5507
#
# Epoch 26/99
# ----------
# train Loss: 0.8553 Acc: 0.6296
# val Loss: 1.2772 Acc: 0.4730
#
# Epoch 27/99
# ----------
# train Loss: 0.7323 Acc: 0.5679
# val Loss: 0.9968 Acc: 0.5473
#
# Epoch 28/99
# ----------
# train Loss: 0.6070 Acc: 0.7531
# val Loss: 1.1225 Acc: 0.5845
#
# Epoch 29/99
# ----------
# train Loss: 0.6768 Acc: 0.7160
# val Loss: 0.9247 Acc: 0.5946
#
# Epoch 30/99
# ----------
# train Loss: 0.6007 Acc: 0.7037
# val Loss: 1.1708 Acc: 0.5811
#
# Epoch 31/99
# ----------
# train Loss: 0.5604 Acc: 0.7407
# val Loss: 2.1432 Acc: 0.5777
#
# Epoch 32/99
# ----------
# train Loss: 1.2808 Acc: 0.6049
# val Loss: 1.6236 Acc: 0.3277
#
# Epoch 33/99
# ----------
# train Loss: 0.8298 Acc: 0.6790
# val Loss: 1.0955 Acc: 0.5642
#
# Epoch 34/99
# ----------
# train Loss: 0.7007 Acc: 0.7284
# val Loss: 1.1905 Acc: 0.4122
#
# Epoch 35/99
# ----------
# train Loss: 0.6549 Acc: 0.6667
# val Loss: 1.5218 Acc: 0.4831
#
# Epoch 36/99
# ----------
# train Loss: 0.6548 Acc: 0.6296
# val Loss: 1.1306 Acc: 0.5473
#
# Epoch 37/99
# ----------
# train Loss: 0.6130 Acc: 0.6667
# val Loss: 1.2621 Acc: 0.5541
#
# Epoch 38/99
# ----------
# train Loss: 0.6246 Acc: 0.7037
# val Loss: 1.1899 Acc: 0.5709
#
# Epoch 39/99
# ----------
# train Loss: 0.6206 Acc: 0.6914
# val Loss: 1.1192 Acc: 0.5709
#
# Epoch 40/99
# ----------
# train Loss: 0.6658 Acc: 0.7284
# val Loss: 1.2330 Acc: 0.5101
#
# Epoch 41/99
# ----------
# train Loss: 0.7607 Acc: 0.5679
# val Loss: 0.9571 Acc: 0.5878
#
# Epoch 42/99
# ----------
# train Loss: 0.6272 Acc: 0.7284
# val Loss: 1.1437 Acc: 0.5845
#
# Epoch 43/99
# ----------
# train Loss: 0.5819 Acc: 0.7160
# val Loss: 1.1812 Acc: 0.5507
#
# Epoch 44/99
# ----------
# train Loss: 0.5686 Acc: 0.7778
# val Loss: 1.1812 Acc: 0.5709
#
# Epoch 45/99
# ----------
# train Loss: 0.6138 Acc: 0.7160
# val Loss: 1.4750 Acc: 0.5709
#
# Epoch 46/99
# ----------
# train Loss: 0.6005 Acc: 0.7160
# val Loss: 1.1101 Acc: 0.5507
#
# Epoch 47/99
# ----------
# train Loss: 0.6277 Acc: 0.6667
# val Loss: 1.3194 Acc: 0.6115
#
# Epoch 48/99
# ----------
# train Loss: 0.5371 Acc: 0.7407
# val Loss: 0.9935 Acc: 0.5912
#
# Epoch 49/99
# ----------
# train Loss: 0.6663 Acc: 0.6790
# val Loss: 1.3503 Acc: 0.5946
#
# Epoch 50/99
# ----------
# train Loss: 0.6251 Acc: 0.6790
# val Loss: 1.0500 Acc: 0.5912
#
# Epoch 51/99
# ----------
# train Loss: 0.6240 Acc: 0.6667
# val Loss: 1.0930 Acc: 0.5878
#
# Epoch 52/99
# ----------
# train Loss: 0.6633 Acc: 0.7284
# val Loss: 1.2662 Acc: 0.5777
#
# Epoch 53/99
# ----------
# train Loss: 0.5954 Acc: 0.7654
# val Loss: 1.0412 Acc: 0.5574
#
# Epoch 54/99
# ----------
# train Loss: 0.5353 Acc: 0.7407
# val Loss: 1.4561 Acc: 0.5338
#
# Epoch 55/99
# ----------
# train Loss: 0.5705 Acc: 0.6790
# val Loss: 1.2154 Acc: 0.5709
#
# Epoch 56/99
# ----------
# train Loss: 0.5268 Acc: 0.8148
# val Loss: 1.3425 Acc: 0.5777
#
# Epoch 57/99
# ----------
# train Loss: 0.6309 Acc: 0.7037
# val Loss: 1.3148 Acc: 0.5473
#
# Epoch 58/99
# ----------
# train Loss: 0.5776 Acc: 0.7901
# val Loss: 1.0917 Acc: 0.6014
#
# Epoch 59/99
# ----------
# train Loss: 0.5968 Acc: 0.7037
# val Loss: 1.3588 Acc: 0.6047
#
# Epoch 60/99
# ----------
# train Loss: 0.5184 Acc: 0.7284
# val Loss: 1.3745 Acc: 0.5980
#
# Epoch 61/99
# ----------
# train Loss: 0.5244 Acc: 0.7284
# val Loss: 1.3569 Acc: 0.6047
#
# Epoch 62/99
# ----------
# train Loss: 0.4940 Acc: 0.7654
# val Loss: 1.4937 Acc: 0.5236
#
# Epoch 63/99
# ----------
# train Loss: 0.5100 Acc: 0.7901
# val Loss: 1.4958 Acc: 0.6115
#
# Epoch 64/99
# ----------
# train Loss: 0.6084 Acc: 0.7160
# val Loss: 1.5212 Acc: 0.5101
#
# Epoch 65/99
# ----------
# train Loss: 0.5714 Acc: 0.7284
# val Loss: 1.1818 Acc: 0.5439
#
# Epoch 66/99
# ----------
# train Loss: 0.5409 Acc: 0.7654
# val Loss: 1.4692 Acc: 0.6115
#
# Epoch 67/99
# ----------
# train Loss: 0.7519 Acc: 0.6667
# val Loss: 1.3150 Acc: 0.5169
#
# Epoch 68/99
# ----------
# train Loss: 0.5020 Acc: 0.7531
# val Loss: 1.2814 Acc: 0.5676
#
# Epoch 69/99
# ----------
# train Loss: 0.5349 Acc: 0.7654
# val Loss: 1.2307 Acc: 0.5946
#
# Epoch 70/99
# ----------
# train Loss: 0.4932 Acc: 0.7778
# val Loss: 1.2515 Acc: 0.5946
#
# Epoch 71/99
# ----------
# train Loss: 0.5318 Acc: 0.7654
# val Loss: 1.2748 Acc: 0.6216
#
# Epoch 72/99
# ----------
# train Loss: 0.4742 Acc: 0.7778
# val Loss: 1.2799 Acc: 0.5642
#
# Epoch 73/99
# ----------
# train Loss: 0.5462 Acc: 0.7407
# val Loss: 1.1090 Acc: 0.6115
#
# Epoch 74/99
# ----------
# train Loss: 0.4794 Acc: 0.7654
# val Loss: 1.6471 Acc: 0.5439
#
# Epoch 75/99
# ----------
# train Loss: 0.6443 Acc: 0.6049
# val Loss: 1.5668 Acc: 0.5507
#
# Epoch 76/99
# ----------
# train Loss: 0.6952 Acc: 0.7160
# val Loss: 2.2264 Acc: 0.5203
#
# Epoch 77/99
# ----------
# train Loss: 0.5654 Acc: 0.7407
# val Loss: 1.0400 Acc: 0.5709
#
# Epoch 78/99
# ----------
# train Loss: 0.5003 Acc: 0.7654
# val Loss: 1.3040 Acc: 0.5270
#
# Epoch 79/99
# ----------
# train Loss: 0.7315 Acc: 0.6543
# val Loss: 1.0897 Acc: 0.6047
#
# Epoch 80/99
# ----------
# train Loss: 0.5806 Acc: 0.6914
# val Loss: 1.5136 Acc: 0.5912
#
# Epoch 81/99
# ----------
# train Loss: 0.7067 Acc: 0.6049
# val Loss: 1.7297 Acc: 0.4628
#
# Epoch 82/99
# ----------
# train Loss: 0.7915 Acc: 0.6420
# val Loss: 1.2130 Acc: 0.6182
#
# Epoch 83/99
# ----------
# train Loss: 0.5764 Acc: 0.6914
# val Loss: 1.2847 Acc: 0.5169
#
# Epoch 84/99
# ----------
# train Loss: 0.5668 Acc: 0.7531
# val Loss: 1.1608 Acc: 0.6081
#
# Epoch 85/99
# ----------
# train Loss: 0.6739 Acc: 0.6667
# val Loss: 1.1470 Acc: 0.4932
#
# Epoch 86/99
# ----------
# train Loss: 0.7001 Acc: 0.6914
# val Loss: 1.4766 Acc: 0.5642
#
# Epoch 87/99
# ----------
# train Loss: 0.5610 Acc: 0.7160
# val Loss: 1.3344 Acc: 0.5068
#
# Epoch 88/99
# ----------
# train Loss: 0.7459 Acc: 0.6049
# val Loss: 1.1405 Acc: 0.5574
#
# Epoch 89/99
# ----------
# train Loss: 0.5614 Acc: 0.7407
# val Loss: 1.1127 Acc: 0.6115
#
# Epoch 90/99
# ----------
# train Loss: 0.6462 Acc: 0.7037
# val Loss: 1.0618 Acc: 0.5980
#
# Epoch 91/99
# ----------
# train Loss: 0.5463 Acc: 0.7407
# val Loss: 1.0519 Acc: 0.5405
#
# Epoch 92/99
# ----------
# train Loss: 0.5606 Acc: 0.7531
# val Loss: 1.1907 Acc: 0.5878
#
# Epoch 93/99
# ----------
# train Loss: 0.5551 Acc: 0.7654
# val Loss: 1.1618 Acc: 0.5676
#
# Epoch 94/99
# ----------
# train Loss: 0.4529 Acc: 0.8025
# val Loss: 1.0883 Acc: 0.5777
#
# Epoch 95/99
# ----------
# train Loss: 0.5631 Acc: 0.7160
# val Loss: 1.2492 Acc: 0.5845
#
# Epoch 96/99
# ----------
# train Loss: 0.4849 Acc: 0.7407
# val Loss: 1.1604 Acc: 0.6047
#
# Epoch 97/99
# ----------
# train Loss: 0.4307 Acc: 0.7901
# val Loss: 1.3066 Acc: 0.5980
#
# Epoch 98/99
# ----------
# train Loss: 0.4605 Acc: 0.7654
# val Loss: 1.3235 Acc: 0.5574
#
# Epoch 99/99
# ----------
# train Loss: 0.5524 Acc: 0.7284
# val Loss: 1.2836 Acc: 0.5676
#
# Training complete in 40m 43s
# Best val Acc: 0.621622

# %%
plt.title("Validation Loss vs. Training Loss, Learning rate : 10^-4")
plt.xlabel("Training Epochs")
plt.ylabel("Loss rate")
plt.plot(range(1,num_epochs+1),train_loss,label="Training Scratch")
plt.plot(range(1,num_epochs+1),val_loss,label="Validation")
plt.ylim((0,1.))
plt.xticks(np.arange(1, num_epochs+1, 1.0))
plt.legend()
plt.rcParams["figure.figsize"] = (40,6)
plt.show()
