# %%
import torch 
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, models, transforms
import time
import torch.nn as nn
import torch.optim as optim
import numpy as np
data_dir = "/home/lbenboudiaf/Bureau/ImagesClassification/dataset/GroceryStoreDataset/dataset/OneClasse"
model_name = "squeezenet"
num_classes = 3
batch_size = 8
num_epochs = 100 #Valeur Initiale par défaut comme dans le TP du Prof 
feature_extract = True
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25, is_inception=False):
    since = time.time()
    
    val_acc_history = []
    
    loss_val = []
    loss_train = []
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # récupéré le model et calculer sa fonction loss 
                    if is_inception and phase == 'train':
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss = loss1 + 0.4*loss2
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase, Backward 
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)
            
            if phase == 'train':
                loss_train.append(epoch_loss)
            else:
                loss_val.append(epoch_loss)
                
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history, loss_train, loss_val
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
#Definition du model Squeezenet.
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    model_ft = None
    input_size = 0

    if model_name == "squeezenet":
        model_ft = models.squeezenet1_0(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        model_ft.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))
        model_ft.num_classes = num_classes
        input_size = 224
    else:
        print("Invalid model name")
        exit()

    return model_ft, input_size

# Initialisé le model pour ce dataset 
model_ft, input_size = initialize_model(model_name, num_classes, feature_extract, use_pretrained=True)
import os
# Augmentaion et normalisation de données pour le jeux d'apprentissage.  
# Normalisation des jeux de test et de validation 
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
        transforms.Resize(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")

# Generation de jeux d'apprentissage et de validation 
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val', 'test']}
# Creation des dataloaders pour jeux d'apprentissage et de validation. 
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val', 'test']}

# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Envoyer le model au GPU
model_ft = model_ft.to(device)
params_to_update = model_ft.parameters()
print("Params to learn:")
if feature_extract:
    params_to_update = []
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)
else:
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            print("\t",name)

# Observation des paramètres sont optimisé 
optimizer_ft = optim.SGD(params_to_update, lr=0.0001, momentum=0.9)
# Out:
# Initializing Datasets and Dataloaders...
# Params to learn:
# 	 classifier.1.weight
# 	 classifier.1.bias

# %%
import copy
import matplotlib.pyplot as plt
scratch_model,_ = initialize_model(model_name, num_classes, feature_extract=False, use_pretrained=False)
scratch_model = scratch_model.to(device)
scratch_optimizer = optim.SGD(scratch_model.parameters(), lr=0.001, momentum=0.9)
scratch_criterion = nn.CrossEntropyLoss()
_,scratch_hist, train_loss, val_loss = train_model(scratch_model, dataloaders_dict, scratch_criterion, scratch_optimizer, num_epochs=num_epochs, is_inception=(model_name=="inception"))

#ohist = []
shist = []

#ohist = [h.cpu().numpy() for h in hist]
shist = [h.cpu().numpy() for h in scratch_hist]
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.0928 Acc: 0.3615
# val Loss: 1.1022 Acc: 0.3885
#
# Epoch 1/99
# ----------
# train Loss: 1.0384 Acc: 0.4932
# val Loss: 1.3925 Acc: 0.3818
#
# Epoch 2/99
# ----------
# train Loss: 1.0070 Acc: 0.5034
# val Loss: 1.3236 Acc: 0.3953
#
# Epoch 3/99
# ----------
# train Loss: 0.9681 Acc: 0.5135
# val Loss: 1.1529 Acc: 0.4324
#
# Epoch 4/99
# ----------
# train Loss: 1.0085 Acc: 0.4865
# val Loss: 1.1081 Acc: 0.3750
#
# Epoch 5/99
# ----------
# train Loss: 1.0676 Acc: 0.3750
# val Loss: 1.0906 Acc: 0.3615
#
# Epoch 6/99
# ----------
# train Loss: 1.0135 Acc: 0.3581
# val Loss: 1.1111 Acc: 0.3615
#
# Epoch 7/99
# ----------
# train Loss: 1.0211 Acc: 0.5034
# val Loss: 1.0887 Acc: 0.4088
#
# Epoch 8/99
# ----------
# train Loss: 0.9400 Acc: 0.5507
# val Loss: 1.1280 Acc: 0.4189
#
# Epoch 9/99
# ----------
# train Loss: 0.8740 Acc: 0.5912
# val Loss: 1.2080 Acc: 0.4358
#
# Epoch 10/99
# ----------
# train Loss: 0.9152 Acc: 0.5743
# val Loss: 1.4630 Acc: 0.4257
#
# Epoch 11/99
# ----------
# train Loss: 0.8710 Acc: 0.5709
# val Loss: 1.1833 Acc: 0.4223
#
# Epoch 12/99
# ----------
# train Loss: 0.8997 Acc: 0.5743
# val Loss: 1.3313 Acc: 0.4561
#
# Epoch 13/99
# ----------
# train Loss: 0.8388 Acc: 0.6047
# val Loss: 2.0972 Acc: 0.3919
#
# Epoch 14/99
# ----------
# train Loss: 0.8940 Acc: 0.5777
# val Loss: 1.3601 Acc: 0.4257
#
# Epoch 15/99
# ----------
# train Loss: 0.8365 Acc: 0.6014
# val Loss: 1.7709 Acc: 0.3851
#
# Epoch 16/99
# ----------
# train Loss: 0.8994 Acc: 0.5608
# val Loss: 1.6263 Acc: 0.4122
#
# Epoch 17/99
# ----------
# train Loss: 0.8578 Acc: 0.6284
# val Loss: 1.6350 Acc: 0.4088
#
# Epoch 18/99
# ----------
# train Loss: 0.8539 Acc: 0.6216
# val Loss: 1.6062 Acc: 0.3784
#
# Epoch 19/99
# ----------
# train Loss: 0.8718 Acc: 0.5912
# val Loss: 1.4254 Acc: 0.4223
#
# Epoch 20/99
# ----------
# train Loss: 0.8427 Acc: 0.6385
# val Loss: 1.5134 Acc: 0.4324
#
# Epoch 21/99
# ----------
# train Loss: 0.8255 Acc: 0.6419
# val Loss: 1.5469 Acc: 0.4324
#
# Epoch 22/99
# ----------
# train Loss: 0.8027 Acc: 0.6419
# val Loss: 1.7901 Acc: 0.4088
#
# Epoch 23/99
# ----------
# train Loss: 0.8760 Acc: 0.5709
# val Loss: 1.4064 Acc: 0.4324
#
# Epoch 24/99
# ----------
# train Loss: 0.8203 Acc: 0.6318
# val Loss: 1.2517 Acc: 0.4392
#
# Epoch 25/99
# ----------
# train Loss: 0.8494 Acc: 0.6014
# val Loss: 1.4126 Acc: 0.4527
#
# Epoch 26/99
# ----------
# train Loss: 0.7905 Acc: 0.6554
# val Loss: 2.0958 Acc: 0.4223
#
# Epoch 27/99
# ----------
# train Loss: 0.7786 Acc: 0.6318
# val Loss: 2.5503 Acc: 0.3818
#
# Epoch 28/99
# ----------
# train Loss: 0.7689 Acc: 0.6486
# val Loss: 1.7670 Acc: 0.4493
#
# Epoch 29/99
# ----------
# train Loss: 0.7896 Acc: 0.6318
# val Loss: 1.8219 Acc: 0.4324
#
# Epoch 30/99
# ----------
# train Loss: 0.7587 Acc: 0.6486
# val Loss: 1.7344 Acc: 0.3919
#
# Epoch 31/99
# ----------
# train Loss: 0.7733 Acc: 0.6723
# val Loss: 1.5608 Acc: 0.3851
#
# Epoch 32/99
# ----------
# train Loss: 0.7439 Acc: 0.6689
# val Loss: 2.9287 Acc: 0.4189
#
# Epoch 33/99
# ----------
# train Loss: 0.8540 Acc: 0.5980
# val Loss: 1.9248 Acc: 0.4020
#
# Epoch 34/99
# ----------
# train Loss: 0.6966 Acc: 0.6791
# val Loss: 1.9552 Acc: 0.4122
#
# Epoch 35/99
# ----------
# train Loss: 0.7513 Acc: 0.6723
# val Loss: 1.4823 Acc: 0.4257
#
# Epoch 36/99
# ----------
# train Loss: 0.7175 Acc: 0.7027
# val Loss: 1.4232 Acc: 0.4189
#
# Epoch 37/99
# ----------
# train Loss: 0.7025 Acc: 0.6757
# val Loss: 1.3637 Acc: 0.4358
#
# Epoch 38/99
# ----------
# train Loss: 0.7088 Acc: 0.6588
# val Loss: 1.6011 Acc: 0.4324
#
# Epoch 39/99
# ----------
# train Loss: 0.8706 Acc: 0.6149
# val Loss: 1.5562 Acc: 0.4459
#
# Epoch 40/99
# ----------
# train Loss: 0.7899 Acc: 0.6216
# val Loss: 2.7463 Acc: 0.4054
#
# Epoch 41/99
# ----------
# train Loss: 0.8259 Acc: 0.6351
# val Loss: 1.6051 Acc: 0.4291
#
# Epoch 42/99
# ----------
# train Loss: 0.7568 Acc: 0.6622
# val Loss: 2.1206 Acc: 0.4189
#
# Epoch 43/99
# ----------
# train Loss: 0.6969 Acc: 0.6926
# val Loss: 2.2422 Acc: 0.4493
#
# Epoch 44/99
# ----------
# train Loss: 0.6987 Acc: 0.6858
# val Loss: 2.8503 Acc: 0.4730
#
# Epoch 45/99
# ----------
# train Loss: 0.6150 Acc: 0.7568
# val Loss: 2.0844 Acc: 0.4122
#
# Epoch 46/99
# ----------
# train Loss: 0.7002 Acc: 0.6723
# val Loss: 1.7125 Acc: 0.4155
#
# Epoch 47/99
# ----------
# train Loss: 0.6907 Acc: 0.7264
# val Loss: 2.0511 Acc: 0.4426
#
# Epoch 48/99
# ----------
# train Loss: 0.7163 Acc: 0.6757
# val Loss: 1.6852 Acc: 0.4493
#
# Epoch 49/99
# ----------
# train Loss: 0.6565 Acc: 0.7162
# val Loss: 3.3840 Acc: 0.4392
#
# Epoch 50/99
# ----------
# train Loss: 0.6966 Acc: 0.7196
# val Loss: 2.1725 Acc: 0.4493
#
# Epoch 51/99
# ----------
# train Loss: 0.5971 Acc: 0.7432
# val Loss: 2.8499 Acc: 0.3953
#
# Epoch 52/99
# ----------
# train Loss: 0.6289 Acc: 0.7264
# val Loss: 2.2681 Acc: 0.4189
#
# Epoch 53/99
# ----------
# train Loss: 0.6989 Acc: 0.7061
# val Loss: 1.7477 Acc: 0.4561
#
# Epoch 54/99
# ----------
# train Loss: 0.5737 Acc: 0.7770
# val Loss: 2.5690 Acc: 0.4020
#
# Epoch 55/99
# ----------
# train Loss: 0.5982 Acc: 0.7399
# val Loss: 2.8386 Acc: 0.4797
#
# Epoch 56/99
# ----------
# train Loss: 0.7292 Acc: 0.6757
# val Loss: 1.8101 Acc: 0.4730
#
# Epoch 57/99
# ----------
# train Loss: 0.6122 Acc: 0.7128
# val Loss: 3.0293 Acc: 0.4155
#
# Epoch 58/99
# ----------
# train Loss: 0.5463 Acc: 0.7872
# val Loss: 3.1267 Acc: 0.4493
#
# Epoch 59/99
# ----------
# train Loss: 0.6073 Acc: 0.7196
# val Loss: 3.4695 Acc: 0.4392
#
# Epoch 60/99
# ----------
# train Loss: 0.6700 Acc: 0.7027
# val Loss: 2.9132 Acc: 0.4493
#
# Epoch 61/99
# ----------
# train Loss: 0.6213 Acc: 0.7399
# val Loss: 2.6543 Acc: 0.4493
#
# Epoch 62/99
# ----------
# train Loss: 0.4924 Acc: 0.7770
# val Loss: 2.8212 Acc: 0.4088
#
# Epoch 63/99
# ----------
# train Loss: 0.5727 Acc: 0.7804
# val Loss: 2.4009 Acc: 0.4561
#
# Epoch 64/99
# ----------
# train Loss: 0.6355 Acc: 0.7331
# val Loss: 1.7223 Acc: 0.4155
#
# Epoch 65/99
# ----------
# train Loss: 0.5159 Acc: 0.7872
# val Loss: 2.9952 Acc: 0.4831
#
# Epoch 66/99
# ----------
# train Loss: 0.5255 Acc: 0.7905
# val Loss: 3.0281 Acc: 0.4493
#
# Epoch 67/99
# ----------
# train Loss: 0.4988 Acc: 0.7703
# val Loss: 2.5586 Acc: 0.4020
#
# Epoch 68/99
# ----------
# train Loss: 0.6149 Acc: 0.7736
# val Loss: 1.7479 Acc: 0.4155
#
# Epoch 69/99
# ----------
# train Loss: 0.5370 Acc: 0.7939
# val Loss: 2.3331 Acc: 0.4189
#
# Epoch 70/99
# ----------
# train Loss: 0.5136 Acc: 0.7804
# val Loss: 3.7389 Acc: 0.4561
#
# Epoch 71/99
# ----------
# train Loss: 0.4902 Acc: 0.8108
# val Loss: 2.6114 Acc: 0.4527
#
# Epoch 72/99
# ----------
# train Loss: 0.4814 Acc: 0.8176
# val Loss: 3.7693 Acc: 0.4324
#
# Epoch 73/99
# ----------
# train Loss: 0.4599 Acc: 0.8108
# val Loss: 3.1224 Acc: 0.3682
#
# Epoch 74/99
# ----------
# train Loss: 0.5509 Acc: 0.7905
# val Loss: 3.7451 Acc: 0.4595
#
# Epoch 75/99
# ----------
# train Loss: 0.4561 Acc: 0.8074
# val Loss: 6.4908 Acc: 0.4291
#
# Epoch 76/99
# ----------
# train Loss: 0.4069 Acc: 0.8480
# val Loss: 2.8368 Acc: 0.4493
#
# Epoch 77/99
# ----------
# train Loss: 0.4708 Acc: 0.8176
# val Loss: 2.6986 Acc: 0.4189
#
# Epoch 78/99
# ----------
# train Loss: 0.5063 Acc: 0.7770
# val Loss: 2.5393 Acc: 0.3649
#
# Epoch 79/99
# ----------
# train Loss: 0.5138 Acc: 0.7973
# val Loss: 2.6880 Acc: 0.4122
#
# Epoch 80/99
# ----------
# train Loss: 0.4319 Acc: 0.8345
# val Loss: 1.9366 Acc: 0.4932
#
# Epoch 81/99
# ----------
# train Loss: 0.5588 Acc: 0.7770
# val Loss: 1.3736 Acc: 0.4426
#
# Epoch 82/99
# ----------
# train Loss: 0.5245 Acc: 0.8108
# val Loss: 2.3039 Acc: 0.3953
#
# Epoch 83/99
# ----------
# train Loss: 0.5069 Acc: 0.7905
# val Loss: 2.4457 Acc: 0.3818
#
# Epoch 84/99
# ----------
# train Loss: 0.5158 Acc: 0.7736
# val Loss: 4.9136 Acc: 0.4155
#
# Epoch 85/99
# ----------
# train Loss: 0.4482 Acc: 0.8345
# val Loss: 2.7387 Acc: 0.3953
#
# Epoch 86/99
# ----------
# train Loss: 0.3902 Acc: 0.8480
# val Loss: 3.7930 Acc: 0.4189
#
# Epoch 87/99
# ----------
# train Loss: 0.3920 Acc: 0.8547
# val Loss: 5.1021 Acc: 0.4189
#
# Epoch 88/99
# ----------
# train Loss: 0.4439 Acc: 0.8378
# val Loss: 4.1634 Acc: 0.4324
#
# Epoch 89/99
# ----------
# train Loss: 0.4296 Acc: 0.8074
# val Loss: 1.9468 Acc: 0.3615
#
# Epoch 90/99
# ----------
# train Loss: 0.5175 Acc: 0.7939
# val Loss: 1.8962 Acc: 0.3784
#
# Epoch 91/99
# ----------
# train Loss: 0.4367 Acc: 0.8378
# val Loss: 2.3047 Acc: 0.3919
#
# Epoch 92/99
# ----------
# train Loss: 0.4526 Acc: 0.8142
# val Loss: 2.4212 Acc: 0.4257
#
# Epoch 93/99
# ----------
# train Loss: 0.3407 Acc: 0.8649
# val Loss: 3.7654 Acc: 0.3919
#
# Epoch 94/99
# ----------
# train Loss: 0.6009 Acc: 0.7365
# val Loss: 1.7922 Acc: 0.4054
#
# Epoch 95/99
# ----------
# train Loss: 0.4094 Acc: 0.8311
# val Loss: 3.7015 Acc: 0.4324
#
# Epoch 96/99
# ----------
# train Loss: 0.3035 Acc: 0.8953
# val Loss: 5.3021 Acc: 0.4595
#
# Epoch 97/99
# ----------
# train Loss: 0.3464 Acc: 0.8615
# val Loss: 2.7501 Acc: 0.3919
#
# Epoch 98/99
# ----------
# train Loss: 0.6411 Acc: 0.7703
# val Loss: 1.4788 Acc: 0.4628
#
# Epoch 99/99
# ----------
# train Loss: 0.4725 Acc: 0.8142
# val Loss: 1.4731 Acc: 0.4628
#
# Training complete in 46m 51s
# Best val Acc: 0.493243

# %%
import matplotlib.pyplot as plt
plt.title("Validation Loss vs. Training Loss, Learning rate : 10^-4")
plt.xlabel("Training Epochs")
plt.ylabel("Loss rate")
plt.plot(range(1,num_epochs+1),train_loss,label="Training Scratch")
plt.plot(range(1,num_epochs+1),val_loss,label="Validation")
plt.ylim((0,6.))
plt.xticks(np.arange(1, num_epochs+1, 1.0))
plt.legend()
plt.rcParams["figure.figsize"] = (40,6)
plt.show()
