# %%
import torch 
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, models, transforms
import time
import torch.nn as nn
import torch.optim as optim
import numpy as np
data_dir = "/home/lbenboudiaf/Bureau/ImagesClassification/dataset/GroceryStoreDataset/dataset/OneClasse"
model_name = "squeezenet"
num_classes = 3
batch_size = 8
num_epochs = 100 #Valeur Initiale par défaut comme dans le TP du Prof 
feature_extract = True
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25, is_inception=False):
    since = time.time()
    
    val_acc_history = []
    
    loss_val = []
    loss_train = []
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # récupéré le model et calculer sa fonction loss 
                    if is_inception and phase == 'train':
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss = loss1 + 0.4*loss2
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase, Backward 
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)
            
            if phase == 'train':
                loss_train.append(epoch_loss)
            else:
                loss_val.append(epoch_loss)
                
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history, loss_train, loss_val
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
#Definition du model Squeezenet.
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    model_ft = None
    input_size = 0

    if model_name == "squeezenet":
        model_ft = models.squeezenet1_0(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        model_ft.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))
        model_ft.num_classes = num_classes
        input_size = 224
    else:
        print("Invalid model name")
        exit()

    return model_ft, input_size

# Initialisé le model pour ce dataset 
model_ft, input_size = initialize_model(model_name, num_classes, feature_extract, use_pretrained=True)
import os
# Augmentaion et normalisation de données pour le jeux d'apprentissage.  
# Normalisation des jeux de test et de validation 
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
        transforms.Resize(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")

# Generation de jeux d'apprentissage et de validation 
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val', 'test']}
# Creation des dataloaders pour jeux d'apprentissage et de validation. 
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val', 'test']}

# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Envoyer le model au GPU
model_ft = model_ft.to(device)
params_to_update = model_ft.parameters()
print("Params to learn:")
if feature_extract:
    params_to_update = []
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)
else:
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            print("\t",name)

# Observation des paramètres sont optimisé 
optimizer_ft = optim.SGD(params_to_update, lr=0.001, momentum=0.9)
# Out:
# Initializing Datasets and Dataloaders...
# Params to learn:
# 	 classifier.1.weight
# 	 classifier.1.bias

# %%
import copy
import matplotlib.pyplot as plt
scratch_model,_ = initialize_model(model_name, num_classes, feature_extract=False, use_pretrained=False)
scratch_model = scratch_model.to(device)
scratch_optimizer = optim.SGD(scratch_model.parameters(), lr=0.001, momentum=0.9)
scratch_criterion = nn.CrossEntropyLoss()
_,scratch_hist, train_loss, val_loss = train_model(scratch_model, dataloaders_dict, scratch_criterion, scratch_optimizer, num_epochs=num_epochs, is_inception=(model_name=="inception"))

#ohist = []
shist = []

#ohist = [h.cpu().numpy() for h in hist]
shist = [h.cpu().numpy() for h in scratch_hist]
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.1078 Acc: 0.3750
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 1/99
# ----------
# train Loss: 1.0986 Acc: 0.3176
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 2/99
# ----------
# train Loss: 1.0988 Acc: 0.3007
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 3/99
# ----------
# train Loss: 1.0985 Acc: 0.3176
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 4/99
# ----------
# train Loss: 1.0984 Acc: 0.3378
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 5/99
# ----------
# train Loss: 1.0985 Acc: 0.3446
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 6/99
# ----------
# train Loss: 1.0977 Acc: 0.3378
# val Loss: 1.0986 Acc: 0.3074
#
# Epoch 7/99
# ----------
# train Loss: 1.0989 Acc: 0.3378
# val Loss: 1.0980 Acc: 0.3378
#
# Epoch 8/99
# ----------
# train Loss: 1.0952 Acc: 0.3378
# val Loss: 1.0986 Acc: 0.2905
#
# Epoch 9/99
# ----------
# train Loss: 1.0982 Acc: 0.3412
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 10/99
# ----------
# train Loss: 1.0938 Acc: 0.3378
# val Loss: 1.0981 Acc: 0.3378
#
# Epoch 11/99
# ----------
# train Loss: 1.0981 Acc: 0.3378
# val Loss: 1.0972 Acc: 0.3378
#
# Epoch 12/99
# ----------
# train Loss: 1.0830 Acc: 0.3378
# val Loss: 1.0976 Acc: 0.3142
#
# Epoch 13/99
# ----------
# train Loss: 1.0905 Acc: 0.3480
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 14/99
# ----------
# train Loss: 1.0986 Acc: 0.3142
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 15/99
# ----------
# train Loss: 1.0986 Acc: 0.2905
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 16/99
# ----------
# train Loss: 1.0986 Acc: 0.2939
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 17/99
# ----------
# train Loss: 1.0986 Acc: 0.3345
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 18/99
# ----------
# train Loss: 1.0986 Acc: 0.3412
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 19/99
# ----------
# train Loss: 1.0985 Acc: 0.3750
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 20/99
# ----------
# train Loss: 1.0986 Acc: 0.2838
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 21/99
# ----------
# train Loss: 1.0986 Acc: 0.2939
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 22/99
# ----------
# train Loss: 1.0986 Acc: 0.3277
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 23/99
# ----------
# train Loss: 1.0986 Acc: 0.3446
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 24/99
# ----------
# train Loss: 1.0986 Acc: 0.3209
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 25/99
# ----------
# train Loss: 1.0985 Acc: 0.3581
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 26/99
# ----------
# train Loss: 1.0986 Acc: 0.3412
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 27/99
# ----------
# train Loss: 1.0985 Acc: 0.3615
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 28/99
# ----------
# train Loss: 1.0983 Acc: 0.3851
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 29/99
# ----------
# train Loss: 1.0978 Acc: 0.3750
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 30/99
# ----------
# train Loss: 1.1020 Acc: 0.3750
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 31/99
# ----------
# train Loss: 1.0986 Acc: 0.3209
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 32/99
# ----------
# train Loss: 1.0986 Acc: 0.2804
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 33/99
# ----------
# train Loss: 1.0986 Acc: 0.2939
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 34/99
# ----------
# train Loss: 1.0986 Acc: 0.2905
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 35/99
# ----------
# train Loss: 1.0986 Acc: 0.2939
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 36/99
# ----------
# train Loss: 1.0986 Acc: 0.2905
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 37/99
# ----------
# train Loss: 1.0986 Acc: 0.2838
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 38/99
# ----------
# train Loss: 1.0986 Acc: 0.2905
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 39/99
# ----------
# train Loss: 1.0986 Acc: 0.2973
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 40/99
# ----------
# train Loss: 1.0986 Acc: 0.2905
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 41/99
# ----------
# train Loss: 1.0986 Acc: 0.2905
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 42/99
# ----------
# train Loss: 1.0986 Acc: 0.2872
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 43/99
# ----------
# train Loss: 1.0986 Acc: 0.2939
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 44/99
# ----------
# train Loss: 1.0986 Acc: 0.2872
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 45/99
# ----------
# train Loss: 1.0986 Acc: 0.2838
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 46/99
# ----------
# train Loss: 1.0986 Acc: 0.2905
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 47/99
# ----------
# train Loss: 1.0986 Acc: 0.2905
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 48/99
# ----------
# train Loss: 1.0986 Acc: 0.2905
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 49/99
# ----------
# train Loss: 1.0986 Acc: 0.2838
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 50/99
# ----------
# train Loss: 1.0986 Acc: 0.2872
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 51/99
# ----------
# train Loss: 1.0986 Acc: 0.3041
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 52/99
# ----------
# train Loss: 1.0986 Acc: 0.2905
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 53/99
# ----------
# train Loss: 1.0986 Acc: 0.2939
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 54/99
# ----------
# train Loss: 1.0986 Acc: 0.2939
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 55/99
# ----------
# train Loss: 1.0986 Acc: 0.2872
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 56/99
# ----------
# train Loss: 1.0986 Acc: 0.2973
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 57/99
# ----------
# train Loss: 1.0986 Acc: 0.2905
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 58/99
# ----------
# train Loss: 1.0986 Acc: 0.3041
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 59/99
# ----------
# train Loss: 1.0986 Acc: 0.2804
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 60/99
# ----------
# train Loss: 1.0986 Acc: 0.3041
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 61/99
# ----------
# train Loss: 1.0986 Acc: 0.2872
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 62/99
# ----------
# train Loss: 1.0986 Acc: 0.2939
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 63/99
# ----------
# train Loss: 1.0986 Acc: 0.2973
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 64/99
# ----------
# train Loss: 1.0986 Acc: 0.3074
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 65/99
# ----------
# train Loss: 1.0986 Acc: 0.2939
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 66/99
# ----------
# train Loss: 1.0986 Acc: 0.2905
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 67/99
# ----------
# train Loss: 1.0986 Acc: 0.2872
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 68/99
# ----------
# train Loss: 1.0986 Acc: 0.3007
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 69/99
# ----------
# train Loss: 1.0986 Acc: 0.3074
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 70/99
# ----------
# train Loss: 1.0986 Acc: 0.2939
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 71/99
# ----------
# train Loss: 1.0986 Acc: 0.3007
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 72/99
# ----------
# train Loss: 1.0986 Acc: 0.2939
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 73/99
# ----------
# train Loss: 1.0986 Acc: 0.3074
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 74/99
# ----------
# train Loss: 1.0986 Acc: 0.2804
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 75/99
# ----------
# train Loss: 1.0986 Acc: 0.3176
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 76/99
# ----------
# train Loss: 1.0986 Acc: 0.3007
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 77/99
# ----------
# train Loss: 1.0986 Acc: 0.2939
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 78/99
# ----------
# train Loss: 1.0986 Acc: 0.3041
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 79/99
# ----------
# train Loss: 1.0986 Acc: 0.3074
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 80/99
# ----------
# train Loss: 1.0986 Acc: 0.3041
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 81/99
# ----------
# train Loss: 1.0985 Acc: 0.3108
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 82/99
# ----------
# train Loss: 1.0986 Acc: 0.3142
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 83/99
# ----------
# train Loss: 1.0986 Acc: 0.2770
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 84/99
# ----------
# train Loss: 1.0986 Acc: 0.2905
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 85/99
# ----------
# train Loss: 1.0986 Acc: 0.3243
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 86/99
# ----------
# train Loss: 1.0986 Acc: 0.3311
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 87/99
# ----------
# train Loss: 1.0985 Acc: 0.3108
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 88/99
# ----------
# train Loss: 1.0986 Acc: 0.3209
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 89/99
# ----------
# train Loss: 1.0985 Acc: 0.3243
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 90/99
# ----------
# train Loss: 1.0985 Acc: 0.3446
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 91/99
# ----------
# train Loss: 1.0984 Acc: 0.3041
# val Loss: 1.0986 Acc: 0.2872
#
# Epoch 92/99
# ----------
# train Loss: 1.0969 Acc: 0.3615
# val Loss: 1.0981 Acc: 0.3412
#
# Epoch 93/99
# ----------
# train Loss: 1.0584 Acc: 0.3412
# val Loss: 1.5657 Acc: 0.3378
#
# Epoch 94/99
# ----------
# train Loss: 1.0308 Acc: 0.3412
# val Loss: 1.5906 Acc: 0.3750
#
# Epoch 95/99
# ----------
# train Loss: 1.0102 Acc: 0.3885
# val Loss: 2.0786 Acc: 0.3581
#
# Epoch 96/99
# ----------
# train Loss: 1.0176 Acc: 0.4054
# val Loss: 1.4600 Acc: 0.3446
#
# Epoch 97/99
# ----------
# train Loss: 1.0199 Acc: 0.4223
# val Loss: 2.3742 Acc: 0.3446
#
# Epoch 98/99
# ----------
# train Loss: 1.0222 Acc: 0.4054
# val Loss: 1.5810 Acc: 0.3750
#
# Epoch 99/99
# ----------
# train Loss: 0.9967 Acc: 0.3919
# val Loss: 2.6964 Acc: 0.3547
#
# Training complete in 42m 55s
# Best val Acc: 0.375000

# %%
import matplotlib.pyplot as plt
plt.title("Training from scratch vs. Validation")
plt.xlabel("Training Epochs")
plt.ylabel("Loss rate")
plt.plot(range(1,num_epochs+1),train_loss,label="Training Scratch")
plt.plot(range(1,num_epochs+1),val_loss,label="Validation")
plt.ylim((0,2.))
plt.xticks(np.arange(1, num_epochs+1, 1.0))
plt.legend()
plt.rcParams["figure.figsize"] = (30,4)
plt.show()
